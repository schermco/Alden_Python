# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
pwd
# Out:
# 'C:\\Users\\aj\\Downloads\\Alden_Python-master\\Alden_Python-master'

# %%
car_data = pd.read_csv("C:\\Users\\aj\\Downloads\\Alden_Python-master\\Alden_Python-master\\Alden_race_car_Data.csv",sep = ',')
car_data.head(1000)
# Out:
#        id  first_name     last_name  race_number       car_make  \
# 0       1       Janet        Volant           10           Ford
# 1       2       Celia   Kislingbury           11          Scion
# 2       3      Chrysa         Brunn           17          Lexus
# 3       4     Jewelle       Birtley           11           Ford
# 4       5     Armando  Blaszczynski            1           MINI
# 5       6     Findley       Awcoate           17           Audi
# 6       7      Lilith        Telfer           17        Hyundai
# 7       8        Chet        Burgin           10           Ford
# 8       9      Ailene       Breeder           20        Pontiac
# 9      10      Wendye          Dyke           10         Suzuki
# 10     11       Terri          Maso            2        Pontiac
# 11     12   Whittaker        Overel            2         Nissan
# 12     13   Milissent       MacGahy           17      Chevrolet
# 13     14        Mora    Tompkinson            6          Dodge
# ...

# %%
for position in car_data['final_position']:
    if final_position == '1':
        print(average_speed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b4fd740d3d90> in <module>
# ----> 1 for position in (car_data['final_position']):
#       2     if final_position == '1':
#       3         print(average_speed)
#
# NameError: name 'car_data' is not defined
